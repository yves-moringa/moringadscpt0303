# %% [markdown]
# # 1. Business Understanding
#
# Safaricom is a telecommunication company based in Kenya.
#
# Safaricom was formed in 1997 as a subsidiary of Telkom kenya and ,currently, mainly owned by the Government of kenya (35%) and Vodacom (35%).
#
# Among its products, it offers financial services under the name MPESA.
#
# MPESA can be used as an electronic wallet and can easily transfer money from one individual to another.
#
# In 2013, MPESA ,in collaboration with CBA, introduced MSHWARI to MPESA users, which allowed you to save and borrow money.
#
# A loan taken using MSHWARI is repayable within 30 days. If the loan is not paid, the loan repayment period is extended for an additional 30 days and will be charged an additional 7.5% facilitation fee on the outstanding loan balance.
#
# Another service offered to Safaricom users is Okoa Jahazi.
#
# Okoa Jahazi provides a credit loan to prepaid subscribers with an advance fee of 10% on the loan amount.
#
# The debt is repaid by automatically deducting the outstanding balance when the user tops up.
#
# The Okoa Jahazi debt must be fully repaid within five days; failing to do so gives Safaricom legal means to blacklist the user.
#
# sources:
# safaricom wikipedia: https://en.wikipedia.org/wiki/Safaricom,
# ncba mshwari: https://ke.ncbagroup.com/m-shwari/,
# safaricom mshwari: https://www.safaricom.co.ke/media-center-landing/frequently-asked-questions/m-shwari-faqs-safaricom#:~:text=If%20you%20have%20not%20paid,on%20your%20outstanding%20loan%20balance.
# safaricom okoajahazi: https://www.safaricom.co.ke/media-center-landing/terms-and-conditions/safaricom-auto-okoa-services

# %% [markdown]
# ## 1.1. Business Objectives
#
# The project aims at predicting when a person is defaulting on their loan.
#
# Using the data collected, we build a model that incorporates all the relevant data in order to accurately predict the outcome.
#
# Loan defaulting occurs when a person fails to repay a debt in the agreed period.

# %% [markdown]
# ## 1.2. Situation Assessment
#
# The team is made of 3 aspiring data scientists, Felista Mweni, Samwel Omondi and Yves HAvugimana;
# who will work on building the required model using google collab and github.
#
# The required tools are freely accessible (collab, jupyter and python packages).
#
# The project shall be completed within a week, by November 23rd, 2022.
#
# The dataset being used contains 9 features and 10329 records.
#
# The variables are as follows:
#
# - CUST_TXN_DATE:                 Customer Transaction Date
# - CUST_ID_ACCT1:                 Account Identifier
# - DEPOSIT_AMNT_MPSA:             Amount deposited on Mpesa
# - RCVD_AMNT_MPSA:                Amount received on Mpesa
# - TRSF_FROM_BANK_TO_MPESA_AMNT:  Amount on transfers from Bank on Mpesa
# - MPSA_CREDITS:                  Mpesa credits
# - DAYS_ARTM_LESS_2:              Number of days airtime is less than 2
# - X_NR_TOT_LOAN_AMNT_OKOA_JAZI:  Total loan amount on okoa jahazi
# - LOAN_AGE_DAYSL:                Loan age in days

# %% [markdown]
# ## 1.3. Data Mining Goals
#
# The goal of this project is to accurately predict that a subscriber is defaulting on a loan or not.
#
# The criteria used for assessing is whether a subscriber defaulted is the inability to repay a loan past 90 days.

# %% [markdown]
# ## 1.4. Project Plan
#
# The project is divided in 4 sections:
# - Business understanding: objectives, assessment and planning
# - Data understanding: data collection, description, exploration and verification
# - Data preparation: feature selection, data cleaning, feature engineering and data integration
# - Modeling: model selection, training and evaluation

# %% [markdown]
# # 2. Data Understanding
#
# In order to understand our data, we will have a look at the different aspects of the dataset:
# - the size of the dataset,
# - the types of variables in the dataset,
# - descriptive statistics of the variables and
# - Detecting errors, outliers and missing values

# %% [markdown]
# ## 2.1. Data Collection
#
# The data is obtained directly from NCBA bank database.
#
# The following are the libraries that were used to load and pre-process the data for modeling:
# - pandas,
# - numpy,
# - matplotlib and
# - seaborn

# %%
# importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading and previewing data

df_raw = pd.read_excel("interview_database_raw.xlsx")

print("Data first rows")
display(df_raw.head())
print("\n ---- \n"*3)
print("Data last rows")
display(df_raw.tail())
# Out:
# Data first rows
#    CUST_TXN_DATE  CUST_ID_ACCT1  DEPOSIT_AMNT_MPSA  RCVD_AMNT_MPSA  \
# 0       20160201        3008009              27590         53226.0
# 1       20160201       12083048               2140             0.0
# 2       20160201       12930260              25700         37974.0
# 3       20160201        6422098               9250          2180.0
# 4       20160201        5395787             102401          7169.0
#
#    TRSF_FROM_BANK_TO_MPESA_AMNT  MPSA_CREDITS  DAYS_ARTM_LESS_2  \
# 0                           0.0       80816.0               139
# 1                        2170.0        4310.0               154
# 2                       38972.0      102646.0                 1
# 3                           0.0       11430.0                64
# 4                           0.0      109570.0                53
#
#    X_NR_TOT_LOAN_AMNT_OKOA_JAZI  LOAN_AGE_DAYS
# 0                         800.0              5
# 1                           0.0              8
# 2                           0.0             27
# 3                           0.0              5
# 4                         450.0             31
#  ----
#
#  ----
#
#  ----
#
# Data last rows
#        CUST_TXN_DATE  CUST_ID_ACCT1  DEPOSIT_AMNT_MPSA  RCVD_AMNT_MPSA  \
# 10324       20160229        7261105              13490             0.0
# 10325       20160229         101780                200          7274.0
# 10326       20160229         101780                200          7274.0
# 10327       20160229       11654130              31000         43544.0
# 10328       20160229        9064758              48640          1897.0
#
#        TRSF_FROM_BANK_TO_MPESA_AMNT  MPSA_CREDITS  DAYS_ARTM_LESS_2  \
# 10324                       24000.0       37490.0                 0
# 10325                           0.0        7474.0               158
# 10326                           0.0        7474.0               158
# 10327                           0.0       74544.0               128
# 10328                           0.0       50537.0                35
#
#        X_NR_TOT_LOAN_AMNT_OKOA_JAZI  LOAN_AGE_DAYS
# 10324                           0.0            287
# 10325                           0.0              8
# 10326                           0.0              8
# 10327                           0.0              5
# 10328                          10.0              9

# %% [markdown]
# All variables in our dataset appear to be numerical, both integers and float numbers can be seen.

# %% [markdown]
# ## 2.2. Data Description
#
# We check the size of our dataset as well as the types of variables we have.

# %%
# Checking the size of the dataset

(rows, cols) = df_raw.shape

print(f"Our dataset has {rows} rows and {cols} columns")
# Out:
# Our dataset has 10329 rows and 9 columns

# %%
# Column names and their data types

df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10329 entries, 0 to 10328
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   CUST_TXN_DATE                 10329 non-null  int64
#  1   CUST_ID_ACCT1                 10329 non-null  int64
#  2   DEPOSIT_AMNT_MPSA             10329 non-null  int64
#  3   RCVD_AMNT_MPSA                10329 non-null  float64
#  4   TRSF_FROM_BANK_TO_MPESA_AMNT  10329 non-null  float64
#  5   MPSA_CREDITS                  10329 non-null  float64
#  6   DAYS_ARTM_LESS_2              10329 non-null  int64
#  7   X_NR_TOT_LOAN_AMNT_OKOA_JAZI  10329 non-null  float64
#  8   LOAN_AGE_DAYS                 10329 non-null  int64
# dtypes: float64(4), int64(5)
# memory usage: 726.4 KB

# %% [markdown]
# The dataset has 9 variables
#
# CUST_TXN_DATE:  Customer Transaction Date - dates from February 1st to February 29th, 2016
# CUST_ID_ACCT1:  Account Identifier
# DEPOSIT_AMNT_MPSA: Amount deposited on Mpesa
# RCVD_AMNT_MPSA: Amount received on Mpesa
# TRSF_FROM_BANK_TO_MPESA_AMNT: Amount on transfers from Bank on Mpesa
# MPSA_CREDITS: Mpesa credits
# DAYS_ARTM_LESS_2: Number of days airtime is less than 2
# X_NR_TOT_LOAN_AMNT_OKOA_JAZI: Total loan amount on okoa jahazi
# LOAN_AGE_DAYSL: Loan age in days
#
# The dataset has 5 integer variables (int64) and 4 variables of float64 type.
#
# All variable datatypes should be in interger form except the date that shall be in date format.

# %%
# creating dataset with correct names

df = df_raw.copy()

# Changing column names

df.rename(columns = {'CUST_TXN_DATE':'customer_transaction_date',
                     'CUST_ID_ACCT1':'account_identifier',
                     'DEPOSIT_AMNT_MPSA': 'amount_deposited',
                     'RCVD_AMNT_MPSA': 'amount_received',
                     'TRSF_FROM_BANK_TO_MPESA_AMNT': 'amount_transfers_from_bank',
                     'MPSA_CREDITS': 'mpesa_credits',
                     'DAYS_ARTM_LESS_2': 'number_days_airtime<2',
                     'X_NR_TOT_LOAN_AMNT_OKOA_JAZI': 'okoa_jahazi_loan_amount',
                     'LOAN_AGE_DAYS': 'Loan_age'}, 
          inplace = True)

df.columns
# Out:
# Index(['customer_transaction_date', 'account_identifier', 'amount_deposited',
#        'amount_received', 'amount_transfers_from_bank', 'mpesa_credits',
#        'number_days_airtime<2', 'okoa_jahazi_loan_amount', 'Loan_age'],
#       dtype='object')

# %% [markdown]
# All columns are renamed properly.

# %%
# Data Description

df.describe()
# Out:
#        customer_transaction_date  account_identifier  amount_deposited  \
# count               1.032900e+04        1.032900e+04      1.032900e+04
# mean                2.016021e+07        8.416440e+06      1.860261e+04
# std                 7.900788e+00        3.707265e+06      1.331564e+05
# min                 2.016020e+07        5.150000e+02      0.000000e+00
# 25%                 2.016021e+07        5.746064e+06      2.500000e+02
# 50%                 2.016022e+07        9.519227e+06      2.790000e+03
# 75%                 2.016022e+07        1.122943e+07      9.670000e+03
# max                 2.016023e+07        1.366975e+07      7.858300e+06
#
#        amount_received  amount_transfers_from_bank  mpesa_credits  \
# count     1.032900e+04                1.032900e+04   1.032900e+04
# mean      3.060607e+04                5.412641e+03   5.462133e+04
# std       1.892388e+05                4.106180e+04   2.543278e+05
# min       0.000000e+00                0.000000e+00   0.000000e+00
# 25%       2.200000e+02                0.000000e+00   4.684000e+03
# 50%       3.854000e+03                0.000000e+00   1.277400e+04
# 75%       1.756400e+04                0.000000e+00   3.503000e+04
# max       1.260546e+07                1.720000e+06   1.264766e+07
#
#        number_days_airtime<2  okoa_jahazi_loan_amount      Loan_age
# count           10329.000000             10329.000000  10329.000000
# mean               84.179979               309.797822     45.805305
# std                54.897796              1139.253170     78.756136
# min                 0.000000                 0.000000      1.000000
# 25%                35.000000                 0.000000     10.000000
# 50%                95.000000                 0.000000     20.000000
# 75%               130.000000               150.000000     31.000000
# max               182.000000             32100.000000    315.000000

# %% [markdown]
# ## 2.3. Data Quality Verification
#
# We check for quality of data by identfying
# - missing values
# - duplicates
# - outliers

# %%
# Checking for missing values

df.isnull().sum()
# Out:
# customer_transaction_date     0
# account_identifier            0
# amount_deposited              0
# amount_received               0
# amount_transfers_from_bank    0
# mpesa_credits                 0
# number_days_airtime<2         0
# okoa_jahazi_loan_amount       0
# Loan_age                      0
# dtype: int64

# %% [markdown]
# The dataset has no missing values

# %%
# Cheking for duplicates

dups = df.duplicated().sum()

print(f"The dataset has {dups} duplicate rows.")
# Out:
# The dataset has 1342 duplicate rows.

# %%
# Checking for outliers

cols_du = list(df.columns)

# initialize figure with 4 subplots in a row 

fig, ax = plt .subplots( 1, 9, figsize= (20, 6))

# add padding between the subplots 

plt.subplots_adjust(wspace=0.5)

# drawing boxplot for each variable

i = 0

for col in cols_du:
    sns.boxplot (data=df[col], ax=ax[i])
    ax[i].set_xlabel (col)
    i+= 1

# %% [markdown]
# We have 6 variables with outliers and 3 without outliers.
#
# The variables with outliers are:
# - amount_deposited
# - amount_received
# - amount_transfers_from_bank
# - mpesa_credits
# - okoa_jahazi_loan_amount
# - Loan_age

# %% [markdown]
# ## 2.4. Data Exploration
#
# While exploring the data, we look at the distributions of the numerical variables.

# %% [markdown]
# ### 2.4.1. Univariate Analysis
#
# A look at the characteristics and distrbution of each variable

# %%
# A look at the customers identification

uniq_id = df.account_identifier.duplicated().sum()

if uniq_id == 0:
    print(f"The column containing the ID has no duplicates") 
else:
    print(f"The column containing the ID has {uniq_id} duplicates")
# Out:
# The column containing the ID has 1342 duplicates

# %%
# On what dates were the data collected?

dates_freq = pd.DataFrame(df['customer_transaction_date'].value_counts())

dates_freq.sort_index(ascending=True).plot.bar(title='Frequency Table for Dates')

plt.show()

# %% [markdown]
# The data was collected in the month of February 2016.
#
# The 15th of February shows very little data whereas the 16th and 17th show an higher number.

# %%
cols_ua = list(df.drop(["account_identifier","customer_transaction_date"], axis = 1).columns)

i = 0

# drawing histograms for each variable

for col in cols_ua:
    df[col].hist(bins = 40)
    plt.title(col)
    plt.show()
    i+= 1

# %% [markdown]
# The Variables below all have their values mainly around zero and they are skewed to the right.
# - amount_deposited
# - amount_received
# - amount_transfers_from_bank
# - mpesa_credits
# - okoa_jahazi_loan_amount
#
# The variables 'number_days_airtime<2' and 'Loan_age' have show the characteristics of a mixture ditribution.

# %% [markdown]
# The distribution of loan age is skewed to the right.
# The majority of the customers have loans that are less than 90 days.

# %%
# Loans less than 90 days
sns.displot(df[df['Loan_age'] <= 90]['Loan_age'])
plt.show()

# %%
# Loans more than 90 days
sns.displot(df[df['Loan_age'] > 90]['Loan_age'])
plt.show()

# %% [markdown]
# ### 2.4.2. Bivariate Analysis

# %%
#Create a pair plot
sns.pairplot(data=df, diag_kind= 'kde')

plt.show()

# %% [markdown]
# ### 2.4.3. Multivariate Analysis

# %%
# Correlation Matrix

corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')

plt.show()

# %% [markdown]
# # 3. Data Preparation

# %% [markdown]
# ## 3.1. Feature Selection
#
# Remove the columns that are not needed for our modeling;
# - customer_transaction_date and
# - account_identifier

# %%
df_prep = df.copy()

df_prep.drop(['customer_transaction_date', 'account_identifier'], axis = 1, inplace = True)

# %% [markdown]
# ## 3.2. Data Cleaning
#
# Cleaning the dataset involves removing outliers and duplicate values.
# Also the data cleaning process involves involves removing/replacing erronous data.
#
# we identified:
# - no missing values
# - 1342 duplicate rows
# - outliers in several columns: **identify the columns

# %%
# Removing Duplicate records

df_prep.drop_duplicates(inplace = True)

(rows_nodups, cols_nodups) = df_prep.shape

print(f"The resulting dataset has {rows_nodups} records and {cols_nodups} features.")
# Out:
# The resulting dataset has 8981 records and 7 features.

# %%
# Removing outliers

# percentile25 = df['amount_deposited'].quantile(0.25)
# percentile75 = df['amount_deposited'].quantile(0.75)

# print("75th quartile: ",percentile75)
# print("25th quartile: ",percentile25)

# iqr = percentile75 - percentile25
# print ("IQR: ",iqr)

# amount_deposited_outlier = df[(df['amount_deposited'] < percentile75 - 1.5 * iqr)
# |(df['amount_deposited'] > percentile25 + 1.5 * iqr)]

# %%
# The columns you want to search for outliers

cols_dp = list(df_prep.columns)

# Calculate quantiles and IQR
Q1 = df_prep[cols_dp].quantile(0.25) # Same as np.percentile but maps (0,1) and not (0,100)
Q3 = df_prep[cols_dp].quantile(0.75)
IQR = Q3 - Q1

# Return a boolean array of the rows with (any) non-outlier column values
condition = ~((df_prep[cols_dp] < (Q1 - 1.5 * IQR)) | (df_prep[cols_dp] > (Q3 + 1.5 * IQR))).any(axis=1)

# Filter our dataframe based on condition

df_no_out = df_prep[condition]

# Shape of dataset with no outliers

(rows3, cols3) = df_no_out.shape

print(f"The dataset with no outliers has {rows3} records and {cols3} columns")
# Out:
# The dataset with no outliers has 3775 records and 7 columns

# %% [markdown]
# ## 3.3. Feature Engineering

# %%
df_prep.columns
# Out:
# Index(['amount_deposited', 'amount_received', 'amount_transfers_from_bank',
#        'mpesa_credits', 'number_days_airtime<2', 'okoa_jahazi_loan_amount',
#        'Loan_age'],
#       dtype='object')

# %%
# Transforming outcome variable from a numerical variable into a binary categorical variable with:
# 0 : loan age < 90 meaning loan not defaulted
# 1 : loan age >= 90 meaning loan is defaulted

df_prep['risk'] = np.where(df_prep['Loan_age'] > 90, 1, 0)

df_prep.head(1)
# Out:
#    amount_deposited  amount_received  amount_transfers_from_bank  \
# 0             27590          53226.0                         0.0
#
#    mpesa_credits  number_days_airtime<2  okoa_jahazi_loan_amount  Loan_age  \
# 0        80816.0                    139                    800.0         5
#
#    risk
# 0     0

# %%
#bar plot for the risk column
df_prep['risk'].value_counts().plot.bar(title='Frequency Distribution of Risk')

plt.show()

# %%
# Creating a final dataset to be used in our modeling

df_final = df_prep.copy()

df_final.drop('Loan_age', axis = 1, inplace = True)

df_final.head(1)
# Out:
#    amount_deposited  amount_received  amount_transfers_from_bank  \
# 0             27590          53226.0                         0.0
#
#    mpesa_credits  number_days_airtime<2  okoa_jahazi_loan_amount  risk
# 0        80816.0                    139                    800.0     0

# %% [markdown]
# # 4. Modeling
#
# Our project consists of predicting whether an individual will default on a loan or not.
# Our target variable "risk" takes on the values 0 and 1.
# Hence we use a classification algorithm.

# %% [markdown]
# ## 4.1. Model Selection
#
# We will use Tensorflow as our classification algorithm.
# More models will be used in order to challenge our results.

# %%
# We import all the libraries required for our modeling

# For train test split modeling
from sklearn.model_selection import train_test_split

# Import a standardization library
from sklearn.preprocessing import StandardScaler

# Import an Multi-Layer Perceptron Classifier model estimator from Scikit-Learn's neural_network library
from sklearn.neural_network import MLPClassifier

#Tensorflow Libraries
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import load_model

# Model evaluation libraries
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# ## 4.2. Train - Test - Split Design
#
# We use the train-test split algorithm on our dataset to perform our modeling.
# First we separate our target variable from the rest of the dataset.

# %%
# First we separate our target variable from the rest of the dataset.

X = df_final.drop('risk', axis = 1)

y = df_final.risk

# %%
# We split the data into train and test datasets

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Normalizing our training Data

# Initialize the scaler
scaler = StandardScaler()

# Fitting the scaler
scaler.fit(X_train)

# Applying the transformation to the data
X_train = scaler.transform(X_train)

X_test = scaler.transform(X_test)

# %% [markdown]
# ## 4.3. Model Training
#
# The choice of our model is "sequential".

# %%
# Number of features

print(f"The number of features is {X.shape[1]}, hence we choose the first layer of the neural network with {X.shape[1]} nodes")
# Out:
# The number of features is 6, hence we choose the first layer of the neural network with 6 nodes

# %%
# Modeling usinf train dataset and fitting to test dataset

model = Sequential()

model.add(
        Dense(7, activation='relu')
)

model.add(
        Dense(5, activation='relu')
)

model.add(
        Dense(3, activation='relu')
)


model.add(
        Dense(1, activation='sigmoid')
)

model.compile(
        optimizer='adam', 
        loss='binary_crossentropy', 
        metrics=['accuracy']
)

early_stop = EarlyStopping(
        monitor='val_loss', 
        mode='min', 
        verbose=1, 
        patience=25
)

model.fit(
        X_train, 
        y_train, 
        epochs=200, 
        batch_size=500, 
        validation_data=(X_test, y_test),
         callbacks=[early_stop]
)
# Out:
# Epoch 1/200
# 15/15 [==============================] - 2s 33ms/step - loss: 0.7091 - accuracy: 0.6059 - val_loss: 0.6978 - val_accuracy: 0.6539
# Epoch 2/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.6933 - accuracy: 0.7652 - val_loss: 0.6854 - val_accuracy: 0.8470
# Epoch 3/200
# 15/15 [==============================] - 0s 8ms/step - loss: 0.6841 - accuracy: 0.8413 - val_loss: 0.6781 - val_accuracy: 0.8720
# Epoch 4/200
# 15/15 [==============================] - 0s 12ms/step - loss: 0.6772 - accuracy: 0.8580 - val_loss: 0.6716 - val_accuracy: 0.8826
# Epoch 5/200
# 15/15 [==============================] - 0s 13ms/step - loss: 0.6710 - accuracy: 0.8679 - val_loss: 0.6655 - val_accuracy: 0.8893
# Epoch 6/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.6650 - accuracy: 0.8722 - val_loss: 0.6596 - val_accuracy: 0.8932
# Epoch 7/200
# 15/15 [==============================] - 0s 9ms/step - loss: 0.6593 - accuracy: 0.8757 - val_loss: 0.6539 - val_accuracy: 0.8965
# Epoch 8/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6538 - accuracy: 0.8778 - val_loss: 0.6483 - val_accuracy: 0.8971
# Epoch 9/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6484 - accuracy: 0.8785 - val_loss: 0.6429 - val_accuracy: 0.8982
# Epoch 10/200
# 15/15 [==============================] - 0s 10ms/step - loss: 0.6433 - accuracy: 0.8789 - val_loss: 0.6376 - val_accuracy: 0.8982
# Epoch 11/200
# 15/15 [==============================] - 0s 10ms/step - loss: 0.6383 - accuracy: 0.8790 - val_loss: 0.6325 - val_accuracy: 0.8982
# Epoch 12/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6334 - accuracy: 0.8796 - val_loss: 0.6274 - val_accuracy: 0.8982
# Epoch 13/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6286 - accuracy: 0.8796 - val_loss: 0.6224 - val_accuracy: 0.8982
# Epoch 14/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6239 - accuracy: 0.8796 - val_loss: 0.6175 - val_accuracy: 0.8982
# Epoch 15/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6192 - accuracy: 0.8796 - val_loss: 0.6127 - val_accuracy: 0.8982
# Epoch 16/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6147 - accuracy: 0.8796 - val_loss: 0.6079 - val_accuracy: 0.8982
# Epoch 17/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6102 - accuracy: 0.8796 - val_loss: 0.6032 - val_accuracy: 0.8982
# Epoch 18/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6058 - accuracy: 0.8796 - val_loss: 0.5986 - val_accuracy: 0.8982
# Epoch 19/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6015 - accuracy: 0.8796 - val_loss: 0.5941 - val_accuracy: 0.8982
# Epoch 20/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5972 - accuracy: 0.8797 - val_loss: 0.5896 - val_accuracy: 0.8982
# Epoch 21/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5930 - accuracy: 0.8797 - val_loss: 0.5852 - val_accuracy: 0.8982
# Epoch 22/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5889 - accuracy: 0.8797 - val_loss: 0.5809 - val_accuracy: 0.8982
# Epoch 23/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5849 - accuracy: 0.8797 - val_loss: 0.5766 - val_accuracy: 0.8982
# Epoch 24/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5809 - accuracy: 0.8797 - val_loss: 0.5724 - val_accuracy: 0.8982
# Epoch 25/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5769 - accuracy: 0.8797 - val_loss: 0.5683 - val_accuracy: 0.8982
# Epoch 26/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5731 - accuracy: 0.8797 - val_loss: 0.5642 - val_accuracy: 0.8982
# Epoch 27/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5693 - accuracy: 0.8797 - val_loss: 0.5602 - val_accuracy: 0.8982
# Epoch 28/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5655 - accuracy: 0.8797 - val_loss: 0.5563 - val_accuracy: 0.8982
# Epoch 29/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5618 - accuracy: 0.8797 - val_loss: 0.5524 - val_accuracy: 0.8982
# Epoch 30/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5582 - accuracy: 0.8797 - val_loss: 0.5485 - val_accuracy: 0.8982
# Epoch 31/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5547 - accuracy: 0.8797 - val_loss: 0.5447 - val_accuracy: 0.8982
# Epoch 32/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5512 - accuracy: 0.8797 - val_loss: 0.5410 - val_accuracy: 0.8982
# Epoch 33/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5477 - accuracy: 0.8797 - val_loss: 0.5374 - val_accuracy: 0.8982
# Epoch 34/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5443 - accuracy: 0.8797 - val_loss: 0.5338 - val_accuracy: 0.8982
# Epoch 35/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5410 - accuracy: 0.8797 - val_loss: 0.5303 - val_accuracy: 0.8982
# Epoch 36/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5377 - accuracy: 0.8797 - val_loss: 0.5268 - val_accuracy: 0.8982
# Epoch 37/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5345 - accuracy: 0.8797 - val_loss: 0.5234 - val_accuracy: 0.8982
# Epoch 38/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5313 - accuracy: 0.8797 - val_loss: 0.5200 - val_accuracy: 0.8982
# Epoch 39/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5282 - accuracy: 0.8797 - val_loss: 0.5167 - val_accuracy: 0.8982
# Epoch 40/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5251 - accuracy: 0.8797 - val_loss: 0.5134 - val_accuracy: 0.8982
# Epoch 41/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5221 - accuracy: 0.8797 - val_loss: 0.5102 - val_accuracy: 0.8982
# Epoch 42/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5191 - accuracy: 0.8797 - val_loss: 0.5070 - val_accuracy: 0.8982
# Epoch 43/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5162 - accuracy: 0.8797 - val_loss: 0.5039 - val_accuracy: 0.8982
# Epoch 44/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5134 - accuracy: 0.8797 - val_loss: 0.5009 - val_accuracy: 0.8982
# Epoch 45/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5105 - accuracy: 0.8797 - val_loss: 0.4979 - val_accuracy: 0.8982
# Epoch 46/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5078 - accuracy: 0.8797 - val_loss: 0.4949 - val_accuracy: 0.8982
# Epoch 47/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5051 - accuracy: 0.8797 - val_loss: 0.4920 - val_accuracy: 0.8982
# Epoch 48/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5024 - accuracy: 0.8797 - val_loss: 0.4892 - val_accuracy: 0.8982
# Epoch 49/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4998 - accuracy: 0.8797 - val_loss: 0.4863 - val_accuracy: 0.8982
# Epoch 50/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4972 - accuracy: 0.8797 - val_loss: 0.4836 - val_accuracy: 0.8982
# Epoch 51/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4947 - accuracy: 0.8797 - val_loss: 0.4809 - val_accuracy: 0.8982
# Epoch 52/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4922 - accuracy: 0.8797 - val_loss: 0.4782 - val_accuracy: 0.8982
# Epoch 53/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4897 - accuracy: 0.8797 - val_loss: 0.4756 - val_accuracy: 0.8982
# Epoch 54/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4873 - accuracy: 0.8797 - val_loss: 0.4730 - val_accuracy: 0.8982
# Epoch 55/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4850 - accuracy: 0.8797 - val_loss: 0.4705 - val_accuracy: 0.8982
# Epoch 56/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4827 - accuracy: 0.8797 - val_loss: 0.4680 - val_accuracy: 0.8982
# Epoch 57/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4804 - accuracy: 0.8797 - val_loss: 0.4655 - val_accuracy: 0.8982
# Epoch 58/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4781 - accuracy: 0.8797 - val_loss: 0.4631 - val_accuracy: 0.8982
# Epoch 59/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4760 - accuracy: 0.8797 - val_loss: 0.4607 - val_accuracy: 0.8982
# Epoch 60/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4738 - accuracy: 0.8797 - val_loss: 0.4584 - val_accuracy: 0.8982
# Epoch 61/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4717 - accuracy: 0.8797 - val_loss: 0.4561 - val_accuracy: 0.8982
# Epoch 62/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4696 - accuracy: 0.8797 - val_loss: 0.4538 - val_accuracy: 0.8982
# Epoch 63/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4675 - accuracy: 0.8797 - val_loss: 0.4516 - val_accuracy: 0.8982
# Epoch 64/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4655 - accuracy: 0.8797 - val_loss: 0.4494 - val_accuracy: 0.8982
# Epoch 65/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4635 - accuracy: 0.8797 - val_loss: 0.4472 - val_accuracy: 0.8982
# Epoch 66/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4616 - accuracy: 0.8797 - val_loss: 0.4451 - val_accuracy: 0.8982
# Epoch 67/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4597 - accuracy: 0.8797 - val_loss: 0.4430 - val_accuracy: 0.8982
# Epoch 68/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4578 - accuracy: 0.8797 - val_loss: 0.4410 - val_accuracy: 0.8982
# Epoch 69/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4560 - accuracy: 0.8797 - val_loss: 0.4390 - val_accuracy: 0.8982
# Epoch 70/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4542 - accuracy: 0.8797 - val_loss: 0.4370 - val_accuracy: 0.8982
# Epoch 71/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4524 - accuracy: 0.8797 - val_loss: 0.4351 - val_accuracy: 0.8982
# Epoch 72/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4507 - accuracy: 0.8797 - val_loss: 0.4331 - val_accuracy: 0.8982
# Epoch 73/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4489 - accuracy: 0.8797 - val_loss: 0.4312 - val_accuracy: 0.8982
# Epoch 74/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4473 - accuracy: 0.8797 - val_loss: 0.4294 - val_accuracy: 0.8982
# Epoch 75/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4456 - accuracy: 0.8797 - val_loss: 0.4276 - val_accuracy: 0.8982
# Epoch 76/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4440 - accuracy: 0.8797 - val_loss: 0.4258 - val_accuracy: 0.8982
# Epoch 77/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4424 - accuracy: 0.8797 - val_loss: 0.4241 - val_accuracy: 0.8982
# Epoch 78/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4409 - accuracy: 0.8797 - val_loss: 0.4224 - val_accuracy: 0.8982
# Epoch 79/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4393 - accuracy: 0.8797 - val_loss: 0.4207 - val_accuracy: 0.8982
# Epoch 80/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4379 - accuracy: 0.8797 - val_loss: 0.4190 - val_accuracy: 0.8982
# Epoch 81/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4364 - accuracy: 0.8797 - val_loss: 0.4174 - val_accuracy: 0.8982
# Epoch 82/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4349 - accuracy: 0.8797 - val_loss: 0.4158 - val_accuracy: 0.8982
# Epoch 83/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4335 - accuracy: 0.8797 - val_loss: 0.4142 - val_accuracy: 0.8982
# Epoch 84/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4321 - accuracy: 0.8797 - val_loss: 0.4127 - val_accuracy: 0.8982
# Epoch 85/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4307 - accuracy: 0.8797 - val_loss: 0.4111 - val_accuracy: 0.8982
# Epoch 86/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4294 - accuracy: 0.8797 - val_loss: 0.4096 - val_accuracy: 0.8982
# Epoch 87/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4281 - accuracy: 0.8797 - val_loss: 0.4081 - val_accuracy: 0.8982
# Epoch 88/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4268 - accuracy: 0.8797 - val_loss: 0.4067 - val_accuracy: 0.8982
# Epoch 89/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4255 - accuracy: 0.8797 - val_loss: 0.4053 - val_accuracy: 0.8982
# Epoch 90/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4243 - accuracy: 0.8797 - val_loss: 0.4039 - val_accuracy: 0.8982
# Epoch 91/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4230 - accuracy: 0.8797 - val_loss: 0.4025 - val_accuracy: 0.8982
# Epoch 92/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4218 - accuracy: 0.8797 - val_loss: 0.4011 - val_accuracy: 0.8982
# Epoch 93/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4206 - accuracy: 0.8797 - val_loss: 0.3998 - val_accuracy: 0.8982
# Epoch 94/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4195 - accuracy: 0.8797 - val_loss: 0.3985 - val_accuracy: 0.8982
# Epoch 95/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4184 - accuracy: 0.8797 - val_loss: 0.3972 - val_accuracy: 0.8982
# Epoch 96/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4173 - accuracy: 0.8797 - val_loss: 0.3959 - val_accuracy: 0.8982
# Epoch 97/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4162 - accuracy: 0.8797 - val_loss: 0.3947 - val_accuracy: 0.8982
# Epoch 98/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4151 - accuracy: 0.8797 - val_loss: 0.3935 - val_accuracy: 0.8982
# Epoch 99/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4140 - accuracy: 0.8797 - val_loss: 0.3923 - val_accuracy: 0.8982
# Epoch 100/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4130 - accuracy: 0.8797 - val_loss: 0.3911 - val_accuracy: 0.8982
# Epoch 101/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4120 - accuracy: 0.8797 - val_loss: 0.3899 - val_accuracy: 0.8982
# Epoch 102/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4110 - accuracy: 0.8797 - val_loss: 0.3888 - val_accuracy: 0.8982
# Epoch 103/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4100 - accuracy: 0.8797 - val_loss: 0.3877 - val_accuracy: 0.8982
# Epoch 104/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4091 - accuracy: 0.8797 - val_loss: 0.3866 - val_accuracy: 0.8982
# Epoch 105/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4081 - accuracy: 0.8797 - val_loss: 0.3855 - val_accuracy: 0.8982
# Epoch 106/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4072 - accuracy: 0.8797 - val_loss: 0.3845 - val_accuracy: 0.8982
# Epoch 107/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4063 - accuracy: 0.8797 - val_loss: 0.3834 - val_accuracy: 0.8982
# Epoch 108/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4054 - accuracy: 0.8797 - val_loss: 0.3824 - val_accuracy: 0.8982
# Epoch 109/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4046 - accuracy: 0.8797 - val_loss: 0.3814 - val_accuracy: 0.8982
# Epoch 110/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4037 - accuracy: 0.8797 - val_loss: 0.3804 - val_accuracy: 0.8982
# Epoch 111/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4029 - accuracy: 0.8797 - val_loss: 0.3795 - val_accuracy: 0.8982
# Epoch 112/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4021 - accuracy: 0.8797 - val_loss: 0.3785 - val_accuracy: 0.8982
# Epoch 113/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4013 - accuracy: 0.8797 - val_loss: 0.3776 - val_accuracy: 0.8982
# Epoch 114/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4005 - accuracy: 0.8797 - val_loss: 0.3767 - val_accuracy: 0.8982
# Epoch 115/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3998 - accuracy: 0.8797 - val_loss: 0.3758 - val_accuracy: 0.8982
# Epoch 116/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3990 - accuracy: 0.8797 - val_loss: 0.3749 - val_accuracy: 0.8982
# Epoch 117/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3983 - accuracy: 0.8797 - val_loss: 0.3741 - val_accuracy: 0.8982
# Epoch 118/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3976 - accuracy: 0.8797 - val_loss: 0.3732 - val_accuracy: 0.8982
# Epoch 119/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3969 - accuracy: 0.8797 - val_loss: 0.3724 - val_accuracy: 0.8982
# Epoch 120/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3962 - accuracy: 0.8797 - val_loss: 0.3715 - val_accuracy: 0.8982
# Epoch 121/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3955 - accuracy: 0.8797 - val_loss: 0.3707 - val_accuracy: 0.8982
# Epoch 122/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3948 - accuracy: 0.8797 - val_loss: 0.3699 - val_accuracy: 0.8982
# Epoch 123/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3942 - accuracy: 0.8797 - val_loss: 0.3692 - val_accuracy: 0.8982
# Epoch 124/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3936 - accuracy: 0.8797 - val_loss: 0.3684 - val_accuracy: 0.8982
# Epoch 125/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3929 - accuracy: 0.8797 - val_loss: 0.3677 - val_accuracy: 0.8982
# Epoch 126/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3923 - accuracy: 0.8797 - val_loss: 0.3669 - val_accuracy: 0.8982
# Epoch 127/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3917 - accuracy: 0.8797 - val_loss: 0.3662 - val_accuracy: 0.8982
# Epoch 128/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3911 - accuracy: 0.8797 - val_loss: 0.3655 - val_accuracy: 0.8982
# Epoch 129/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3906 - accuracy: 0.8797 - val_loss: 0.3648 - val_accuracy: 0.8982
# Epoch 130/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3900 - accuracy: 0.8797 - val_loss: 0.3641 - val_accuracy: 0.8982
# Epoch 131/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3895 - accuracy: 0.8797 - val_loss: 0.3634 - val_accuracy: 0.8982
# Epoch 132/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3889 - accuracy: 0.8797 - val_loss: 0.3628 - val_accuracy: 0.8982
# Epoch 133/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3884 - accuracy: 0.8797 - val_loss: 0.3621 - val_accuracy: 0.8982
# Epoch 134/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3879 - accuracy: 0.8797 - val_loss: 0.3615 - val_accuracy: 0.8982
# Epoch 135/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3874 - accuracy: 0.8797 - val_loss: 0.3608 - val_accuracy: 0.8982
# Epoch 136/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3869 - accuracy: 0.8797 - val_loss: 0.3602 - val_accuracy: 0.8982
# Epoch 137/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3864 - accuracy: 0.8797 - val_loss: 0.3596 - val_accuracy: 0.8982
# Epoch 138/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3859 - accuracy: 0.8797 - val_loss: 0.3591 - val_accuracy: 0.8982
# Epoch 139/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3854 - accuracy: 0.8797 - val_loss: 0.3585 - val_accuracy: 0.8982
# Epoch 140/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3850 - accuracy: 0.8797 - val_loss: 0.3579 - val_accuracy: 0.8982
# Epoch 141/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3845 - accuracy: 0.8797 - val_loss: 0.3574 - val_accuracy: 0.8982
# Epoch 142/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3841 - accuracy: 0.8797 - val_loss: 0.3568 - val_accuracy: 0.8982
# Epoch 143/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3837 - accuracy: 0.8797 - val_loss: 0.3563 - val_accuracy: 0.8982
# Epoch 144/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3833 - accuracy: 0.8797 - val_loss: 0.3557 - val_accuracy: 0.8982
# Epoch 145/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3829 - accuracy: 0.8797 - val_loss: 0.3552 - val_accuracy: 0.8982
# Epoch 146/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3825 - accuracy: 0.8797 - val_loss: 0.3547 - val_accuracy: 0.8982
# Epoch 147/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3821 - accuracy: 0.8797 - val_loss: 0.3542 - val_accuracy: 0.8982
# Epoch 148/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3817 - accuracy: 0.8797 - val_loss: 0.3537 - val_accuracy: 0.8982
# Epoch 149/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3813 - accuracy: 0.8797 - val_loss: 0.3533 - val_accuracy: 0.8982
# Epoch 150/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3810 - accuracy: 0.8797 - val_loss: 0.3528 - val_accuracy: 0.8982
# Epoch 151/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3806 - accuracy: 0.8797 - val_loss: 0.3523 - val_accuracy: 0.8982
# Epoch 152/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3802 - accuracy: 0.8797 - val_loss: 0.3519 - val_accuracy: 0.8982
# Epoch 153/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.3799 - accuracy: 0.8797 - val_loss: 0.3514 - val_accuracy: 0.8982
# Epoch 154/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.3796 - accuracy: 0.8797 - val_loss: 0.3510 - val_accuracy: 0.8982
# Epoch 155/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3792 - accuracy: 0.8797 - val_loss: 0.3506 - val_accuracy: 0.8982
# Epoch 156/200
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3789 - accuracy: 0.8797 - val_loss: 0.3502 - val_accuracy: 0.8982
# Epoch 157/200
# 15/15 [==============================] - 0s 9ms/step - loss: 0.3786 - accuracy: 0.8797 - val_loss: 0.3497 - val_accuracy: 0.8982
# Epoch 158/200
# 15/15 [==============================] - 0s 13ms/step - loss: 0.3783 - accuracy: 0.8797 - val_loss: 0.3493 - val_accuracy: 0.8982
# Epoch 159/200
# 15/15 [==============================] - 0s 9ms/step - loss: 0.3780 - accuracy: 0.8797 - val_loss: 0.3490 - val_accuracy: 0.8982
# Epoch 160/200
# 15/15 [==============================] - 0s 10ms/step - loss: 0.3777 - accuracy: 0.8797 - val_loss: 0.3486 - val_accuracy: 0.8982
# Epoch 161/200
# 15/15 [==============================] - 0s 12ms/step - loss: 0.3775 - accuracy: 0.8797 - val_loss: 0.3482 - val_accuracy: 0.8982
# Epoch 162/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3772 - accuracy: 0.8797 - val_loss: 0.3478 - val_accuracy: 0.8982
# Epoch 163/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.3769 - accuracy: 0.8797 - val_loss: 0.3474 - val_accuracy: 0.8982
# Epoch 164/200
# 15/15 [==============================] - 0s 6ms/step - loss: 0.3766 - accuracy: 0.8797 - val_loss: 0.3471 - val_accuracy: 0.8982
# Epoch 165/200
# 15/15 [==============================] - 0s 10ms/step - loss: 0.3764 - accuracy: 0.8797 - val_loss: 0.3467 - val_accuracy: 0.8982
# Epoch 166/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.3761 - accuracy: 0.8797 - val_loss: 0.3464 - val_accuracy: 0.8982
# Epoch 167/200
# 15/15 [==============================] - 0s 12ms/step - loss: 0.3759 - accuracy: 0.8797 - val_loss: 0.3460 - val_accuracy: 0.8982
# Epoch 168/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3756 - accuracy: 0.8797 - val_loss: 0.3457 - val_accuracy: 0.8982
# Epoch 169/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3754 - accuracy: 0.8797 - val_loss: 0.3454 - val_accuracy: 0.8982
# Epoch 170/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3752 - accuracy: 0.8797 - val_loss: 0.3450 - val_accuracy: 0.8982
# Epoch 171/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3750 - accuracy: 0.8797 - val_loss: 0.3447 - val_accuracy: 0.8982
# Epoch 172/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3747 - accuracy: 0.8797 - val_loss: 0.3444 - val_accuracy: 0.8982
# Epoch 173/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3745 - accuracy: 0.8797 - val_loss: 0.3441 - val_accuracy: 0.8982
# Epoch 174/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3743 - accuracy: 0.8797 - val_loss: 0.3438 - val_accuracy: 0.8982
# Epoch 175/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3741 - accuracy: 0.8797 - val_loss: 0.3435 - val_accuracy: 0.8982
# Epoch 176/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3739 - accuracy: 0.8797 - val_loss: 0.3433 - val_accuracy: 0.8982
# Epoch 177/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3737 - accuracy: 0.8797 - val_loss: 0.3430 - val_accuracy: 0.8982
# Epoch 178/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3736 - accuracy: 0.8797 - val_loss: 0.3427 - val_accuracy: 0.8982
# Epoch 179/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3734 - accuracy: 0.8797 - val_loss: 0.3425 - val_accuracy: 0.8982
# Epoch 180/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3732 - accuracy: 0.8797 - val_loss: 0.3422 - val_accuracy: 0.8982
# Epoch 181/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3730 - accuracy: 0.8797 - val_loss: 0.3420 - val_accuracy: 0.8982
# Epoch 182/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3729 - accuracy: 0.8797 - val_loss: 0.3417 - val_accuracy: 0.8982
# Epoch 183/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3727 - accuracy: 0.8797 - val_loss: 0.3415 - val_accuracy: 0.8982
# Epoch 184/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3725 - accuracy: 0.8797 - val_loss: 0.3412 - val_accuracy: 0.8982
# Epoch 185/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3724 - accuracy: 0.8797 - val_loss: 0.3410 - val_accuracy: 0.8982
# Epoch 186/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3722 - accuracy: 0.8797 - val_loss: 0.3408 - val_accuracy: 0.8982
# Epoch 187/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3721 - accuracy: 0.8797 - val_loss: 0.3406 - val_accuracy: 0.8982
# Epoch 188/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3720 - accuracy: 0.8797 - val_loss: 0.3403 - val_accuracy: 0.8982
# Epoch 189/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3718 - accuracy: 0.8797 - val_loss: 0.3401 - val_accuracy: 0.8982
# Epoch 190/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3717 - accuracy: 0.8797 - val_loss: 0.3399 - val_accuracy: 0.8982
# Epoch 191/200
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3715 - accuracy: 0.8797 - val_loss: 0.3397 - val_accuracy: 0.8982
# Epoch 192/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3714 - accuracy: 0.8797 - val_loss: 0.3395 - val_accuracy: 0.8982
# Epoch 193/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3713 - accuracy: 0.8797 - val_loss: 0.3393 - val_accuracy: 0.8982
# Epoch 194/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3712 - accuracy: 0.8797 - val_loss: 0.3391 - val_accuracy: 0.8982
# Epoch 195/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3710 - accuracy: 0.8797 - val_loss: 0.3389 - val_accuracy: 0.8982
# Epoch 196/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3709 - accuracy: 0.8797 - val_loss: 0.3387 - val_accuracy: 0.8982
# Epoch 197/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3708 - accuracy: 0.8797 - val_loss: 0.3385 - val_accuracy: 0.8982
# Epoch 198/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3707 - accuracy: 0.8797 - val_loss: 0.3383 - val_accuracy: 0.8982
# Epoch 199/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3706 - accuracy: 0.8797 - val_loss: 0.3382 - val_accuracy: 0.8982
# Epoch 200/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3705 - accuracy: 0.8797 - val_loss: 0.3380 - val_accuracy: 0.8982

# %% [markdown]
# ## 4.4. Model Evaluation and Validation

# %%
pd.DataFrame(model.history.history)[['loss','val_loss']].plot()

plt.title("Loss Plot")

plt.show()

# %% [markdown]
# This validation result, the Loss plot, shows us the model is well fitted.

# %%
accuracy = model.evaluate(X, y)

#print(accuracy)
print("%s: %.2f%%" % (model.metrics_names[1], accuracy[1]*100))
# Out:
# 281/281 [==============================] - 1s 1ms/step - loss: 118.0896 - accuracy: 0.7490
# accuracy: 74.90%

# %% [markdown]
# ## 4.5. Challenging the Solution
#
# we are going to use MPLClassifier class.Multilayer perceptron is used when its output is binary which is our case here.

# %%
# Creating our model
mlp = MLPClassifier(hidden_layer_sizes=(7,7,7), activation='logistic', random_state=10, max_iter=500)# the number of neurons comprising that hidden layer is equal to the number of features (columns) in your data. 

# fitting the data
mlp.fit(X_train,y_train)

# Predicting
y_pred = mlp.predict(X_test)

# Evaluation
print(confusion_matrix(y_test,y_pred))

print('-----------------------------------------')

print(classification_report(y_test,y_pred))
# Out:
# [[1614    0]
#  [ 183    0]]
# -----------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      1614
#            1       0.00      0.00      0.00       183
#
#     accuracy                           0.90      1797
#    macro avg       0.45      0.50      0.47      1797
# weighted avg       0.81      0.90      0.85      1797
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Validating some ML algorithm by its accuracy - Model Score

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold

# %%
models = []
models.append(('LR', LogisticRegression(solver='liblinear', multi_class='ovr')))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC(gamma='auto')))

# %%
from matplotlib import pyplot
results = []
names = []
res = []
for name, model in models:
    kfold = StratifiedKFold(n_splits=10, random_state=None)
    cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring='accuracy')
    results.append(cv_results)
    names.append(name)
    res.append(cv_results.mean())
    print('%s: %f' % (name, cv_results.mean()))
# Out:
# LR: 0.879733
# LDA: 0.879733
# KNN: 0.867484
# CART: 0.781598
# NB: 0.600908
# SVM: 0.879733

# %% [markdown]
# This comparison shows that LOgistic regression,LDA,SVM perform with the same Accuracy. The results also show that our model performs better than the rest with accuracy of 88.35%
